# %% [markdown]
# # Exercise 2 — Title
# **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# ## Exercise 3 — Introduction
# This notebook completes the beginner assignment by adding Markdown and code cells for each exercise, including lists, a tools table, arithmetic examples, and small Python snippets.

# %% [markdown]
# ## Exercise 4 — Data Science Languages
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# ## Exercise 5 — Data Science Libraries
# - NumPy
# - pandas
# - Matplotlib / Plotly
# - scikit-learn
# - TensorFlow / PyTorch

# %% [markdown]
# ## Exercise 6 — Table of Data Science Tools
#
# | Tool         | Category        | Typical Use                              |
# |--------------|-----------------|-------------------------------------------|
# | JupyterLab   | IDE/Notebook    | Interactive notebooks, exploration        |
# | VS Code      | IDE             | General coding, extensions, debugging     |
# | RStudio      | IDE             | R development and notebooks               |
# | Git          | Version Control | Track changes, collaborate                |
# | GitHub       | Hosting         | Share code/notebooks, issues, CI          |
# | Docker       | Containerization| Reproducible environments, deployment     |

# %% [markdown]
# ## Exercise 7 — Arithmetic Expression Examples
# Below we evaluate a couple of simple expressions in Python.

# %%
# Exercise 8 — Multiply and Add Numbers
# Compute (3 * 4) + 5 as an example
(3 * 4) + 5
# Out:
# 17

# %%
# Exercise 9 — Convert Minutes to Hours
def minutes_to_hours(minutes: float) -> float:
    """Return hours given minutes."""
    return minutes / 60.0

example_minutes = 200
minutes_to_hours(example_minutes)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Exercise 10 — Objectives
# - List common data science **languages** and **libraries**
# - Create a **table** of data science tools
# - Run **arithmetic** examples and a **minutes→hours** function
# - Share the notebook on **GitHub**

# %% [markdown]
# ## Exercise 11 — Author
# **Author:** Soumya Bhate

# %% [markdown]
# ## Exercise 12 — Share Your Notebook via GitHub
#
# **Public GitHub URL:** https://github.com/soumyabhate/IBM-Data-Science-Professionals-Course

# %% [markdown]
# ## Exercise 13 — Screenshot of the First Page

# %% [markdown]
# uploaded in the repo itself
